# %% [markdown]
# # Disperser transmission study 'HD205905'
#
#
# Study the true transmission wrt transmission in simulatio
#
# - author Sylvie Dagoret-Campagne
# - creation date : May 2018
# - affliliation : CNRS/IN2P3
# - project : DESC-LSST

# %% [markdown]
# - need to increase the number of files to be open:
#
#     ulimit -a
#
#     ulimit -n 2048
#
#     ulimit -Sn 10000

# %%
# !ulimit -a
# Out:
# core file size          (blocks, -c) 0
# data seg size           (kbytes, -d) unlimited
# file size               (blocks, -f) unlimited
# max locked memory       (kbytes, -l) unlimited
# max memory size         (kbytes, -m) unlimited
# open files                      (-n) 2048
# pipe size            (512 bytes, -p) 1
# stack size              (kbytes, -s) 8192
# cpu time               (seconds, -t) unlimited
# max user processes              (-u) 1418
# virtual memory          (kbytes, -v) unlimited

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Notebook style

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width: 90%;
# /*        margin-left:auto;*/
# /*        margin-right:auto;*/
#     }
#     ul {
#         line-height: 145%;
#         font-size: 90%;
#     }
#     li {
#         margin-bottom: 1em;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top: 12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# ### import

# %%
import matplotlib.pyplot as plt
import sys
import os
import pandas as pd
import glob
from matplotlib.backends.backend_pdf import PdfPages

# %%
from scipy import interpolate

# %%
import seaborn as sns

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Figure style

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 10),   #defines the default image size
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
plt.rcParams.update({'figure.max_open_warning': 0}) # to see a large number of files

# %% [markdown]
# ## Initialisation

# %% [markdown]
# ### Spectractor

# %%
PATH_SPECTRACTOR='../../../Spectractor'
PATH_SPECTRACTORSIM='../../../SpectractorSim'
PATH_SPECTRACTORANAATM='../../../SpectractorAnaAtm/common_tools'
PATH_GMAOMERRA='../../../merra2'

# %%
sys.path.append(PATH_SPECTRACTOR)
sys.path.append(PATH_SPECTRACTORSIM)
sys.path.append(PATH_SPECTRACTORANAATM)
sys.path.append(PATH_GMAOMERRA)

# %%
from spectractor import *
from spectractorsim import *
from libspecana import *

# %% [markdown]
# ## Input spectra

# %% [markdown]
# ### LogBook

# %%
file_logbook_csv=os.path.join(PATH_SPECTRACTOR,'ctiofulllogbook_jun2017_v4.csv')

# %%
df_ctio_lbk=pd.read_csv(file_logbook_csv,sep=';')

# %%
df_ctio_lbk.columns
# Out:
# Index([u'Unnamed: 0', u'date', u'subdir', u'index', u'object', u'filter',
#        u'disperser', u'airmass', u'exposure', u'focus', u'seeing', u'P', u'T',
#        u'RH', u'W', u'file', u'Obj-posXpix', u'Obj-posYpix', u'Dx', u'Dy',
#        u'comment', u'skip'],
#       dtype='object')

# %%
df_ctio_lbk=df_ctio_lbk.reindex(columns=['date','index','P','T','RH','airmass','seeing','exposure','object','filter','disperser','focus','W','subdir','file']).set_index('date').sort_index()

# %% [markdown]
# ### Spectra Data

# %%
home=os.getenv('HOME')

# %%
path_data=os.path.join(home,'DATA/CTIODataJune2017_reduced_RG715_v2_prod1')
#path_data=os.path.join('/sps/lsst/data/AtmosphericCalibration','CTIODataJune2017_reduced_RG715_v2_prod1')

# %%
All_Subdirs=np.array(['data_28may17','data_29may17','data_30may17','data_31may17','data_01jun17','data_02jun17',
            'data_03jun17','data_04jun17','data_06jun17','data_08jun17','data_09jun17','data_10jun17',
            'data_12jun17','data_13jun17'])

# %%
Flag_Photometric_Nights=np.array([False,False,True,False,False,False,False,False,False,True,False,True,True,False])

# %%
photometric_indexes=np.where(Flag_Photometric_Nights)[0]

# %%
print 'Photometric indexes : ',photometric_indexes
# Out:
# Photometric indexes :  [ 2  9 11 12]

# %%
print 'Photometric nights : ',All_Subdirs[photometric_indexes]
# Out:
# Photometric nights :  ['data_30may17' 'data_08jun17' 'data_10jun17' 'data_12jun17']

# %% [markdown]
# ### Sim spectra

# %%
PATH_SPECTRACTORSIM
# Out:
# '../../../SpectractorSim'

# %%
path_sim=os.path.join(PATH_SPECTRACTORSIM,'sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra')
#path_sim=PATH_SPECTRACTORSIM+'/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra'

# %%
path_sim
# Out:
# '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra'

# %% [markdown]
# ## Selection of night

# %%
date="20170530"

# %%
idx_sel_subdir=2

# %%
SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)

# %% [markdown]
# ### Logbook

# %%
all_obs=df_ctio_lbk.loc[(df_ctio_lbk["subdir"]==All_Subdirs[idx_sel_subdir])].sort_index()

# %%
all_obs_extr=all_obs[["index","object"]]

# %% [markdown]
# ### Wavelength correction

# %%
FLAG_WL_CORRECTION=True # specify if correction on wavelength can be performed from input file
file_wavelengthshift="../wavelength_shift.csv"
wlshift=pd.read_csv(file_wavelengthshift)

# %%
wlshift.head()
# Out:
#    index   wlshift
# 0     57 -6.633933
# 1     58 -3.083037
# 2     60 -8.383797
# 3     61 -2.846134
# 4     62 -5.646836

# %% [markdown]
# ### path for spectra

# %%
path_spectra=os.path.join(path_data,All_Subdirs[idx_sel_subdir])
path_spectrasim=os.path.join(path_sim,All_Subdirs[idx_sel_subdir])

# %% [markdown]
# ### find filename for data spectra

# %%
search_string=os.path.join(path_spectra,'*.fits')
all_spectrafiles=glob.glob(search_string)
all_spectrafiles=sorted(all_spectrafiles)

# %% [markdown]
# ### extract the index from the data spectra filename

# %%
#SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
all_sel_indexes=[]
for ffn in all_spectrafiles:
    all_sel_indexes.append(get_index_from_filename(ffn,SelectTagRe))
all_sel_indexes=np.array(all_sel_indexes)

# %% [markdown]
# ### extract the logbook rows corrsponding to the spectra
#
# - use the indexes obtained to extract the relevant rows from the logbook

# %%
sel_obs=all_obs.loc[all_obs['index'].isin(all_sel_indexes)]

# %%
sel_obs.head()
# Out:
#                          index    P    T  RH airmass seeing exposure  \
# date
# 2017-05-31T00:00:26.147     57  783  9,3  26   1,053   1,14       60
# 2017-05-31T00:02:18.596     58  783  9,3  26   1,051   0,94       60
# 2017-05-31T00:06:14.000     60  783  9,1  26   1,047  1,018       60
# 2017-05-31T00:08:06.454     61  783  9,2  26   1,045  0,939       60
# 2017-05-31T00:09:58.852     62  783  9,1  26   1,044  0,846       60
#
#                            object filter disperser  focus    W        subdir  \
# date
# 2017-05-31T00:00:26.147  HD111980    dia    Ron400  12450  5,7  data_30may17
# 2017-05-31T00:02:18.596  HD111980    dia   Thor300  12450  5,5  data_30may17
# 2017-05-31T00:06:14.000  HD111980    dia    Ron400  12450  5,7  data_30may17
# 2017-05-31T00:08:06.454  HD111980    dia   Thor300  12450  5,5  data_30may17
# 2017-05-31T00:09:58.852  HD111980    dia   HoloPhP  12450  5,8  data_30may17
#
#                                             file
# date
# 2017-05-31T00:00:26.147  reduc_20170530_057.fits
# 2017-05-31T00:02:18.596  reduc_20170530_058.fits
# 2017-05-31T00:06:14.000  reduc_20170530_060.fits
# 2017-05-31T00:08:06.454  reduc_20170530_061.fits
# 2017-05-31T00:09:58.852  reduc_20170530_062.fits

# %%
sel_obs.tail()
# Out:
#                          index    P     T  RH airmass seeing exposure  \
# date
# 2017-05-31T10:33:46.896    280  782    11  20   1,018  0,793       60
# 2017-05-31T10:35:39.245    281  782  11,2  20   1,019  0,793       60
# 2017-05-31T10:37:31.598    282  782    11  20   1,021  0,793       60
# 2017-05-31T10:39:24.046    283  782    11  20   1,022  0,793      120
# 2017-05-31T10:42:16.450    284  782    11  20   1,024  0,793      120
#
#                            object filter disperser  focus     W        subdir  \
# date
# 2017-05-31T10:33:46.896  HD205905    dia    Ron400  12400  14,5  data_30may17
# 2017-05-31T10:35:39.245  HD205905    dia   Thor300  12400  13,1  data_30may17
# 2017-05-31T10:37:31.598  HD205905    dia   HoloPhP  12400  12,5  data_30may17
# 2017-05-31T10:39:24.046  HD205905    dia  HoloPhAg  12400  12,8  data_30may17
# 2017-05-31T10:42:16.450  HD205905    dia  HoloAmAg  12400  13,2  data_30may17
#
#                                             file
# date
# 2017-05-31T10:33:46.896  reduc_20170530_280.fits
# 2017-05-31T10:35:39.245  reduc_20170530_281.fits
# 2017-05-31T10:37:31.598  reduc_20170530_282.fits
# 2017-05-31T10:39:24.046  reduc_20170530_283.fits
# 2017-05-31T10:42:16.450  reduc_20170530_284.fits

# %% [markdown]
# ### Quick view on the kind of sources

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='object', data=sel_obs)
plt.grid(True)

# %%
plt.figure(figsize=(5,3))
sel_obs['object'].value_counts().plot(kind='bar',rot=0)
plt.xticks(rotation=-45)
plt.grid(True)

# %% [markdown]
# ### Remove bad spectra

# %%
bad_obs_0=sel_obs.loc[sel_obs['index'].isin([57])]

# %%
bad_obs_0
# Out:
#                          index    P    T  RH airmass seeing exposure  \
# date
# 2017-05-31T00:00:26.147     57  783  9,3  26   1,053   1,14       60
#
#                            object filter disperser  focus    W        subdir  \
# date
# 2017-05-31T00:00:26.147  HD111980    dia    Ron400  12450  5,7  data_30may17
#
#                                             file
# date
# 2017-05-31T00:00:26.147  reduc_20170530_057.fits

# %% [markdown]
# ### Remove bad sources
#
# - remove star **PNG336.3-05.6**

# %%
bad_obs=sel_obs.loc[sel_obs['object'].isin(['PNG336.3-05.6','HD111980'])]
bad_indexes=bad_obs["index"]

# %%
bad_obs
# Out:
#                          index    P    T  RH airmass seeing exposure  \
# date
# 2017-05-31T00:00:26.147     57  783  9,3  26   1,053   1,14       60
# 2017-05-31T00:02:18.596     58  783  9,3  26   1,051   0,94       60
# 2017-05-31T00:06:14.000     60  783  9,1  26   1,047  1,018       60
# 2017-05-31T00:08:06.454     61  783  9,2  26   1,045  0,939       60
# 2017-05-31T00:09:58.852     62  783  9,1  26   1,044  0,846       60
# 2017-05-31T00:11:51.243     63  783  8,9  26   1,042   0,83      120
# 2017-05-31T00:14:43.647     64  783  8,9  26    1,04   0,74      120
# 2017-05-31T00:17:36.001     65  783  8,8  26   1,037  0,771       60
# 2017-05-31T00:19:28.503     66  783  8,8  26   1,036  0,715       60
# 2017-05-31T00:21:20.951     67  783  8,7  26   1,035  0,954       60
# 2017-05-31T00:23:13.357     68  783  8,6  26   1,033  0,714      120
# 2017-05-31T00:26:05.798     69  783  8,7  26   1,032  0,714      120
# 2017-05-31T00:28:58.154     70  783  8,7  26    1,03   0,82       60
# 2017-05-31T00:30:50.597     71  783  8,6  26   1,029  0,843       60
# 2017-05-31T00:32:43.005     72  783  8,6  26   1,028  0,741       60
# 2017-05-31T00:34:35.343     73  783  8,5  27   1,027  0,744      120
# 2017-05-31T00:37:27.804     74  783  8,6  27   1,026  0,821      120
# 2017-05-31T00:40:20.202     75  783  8,6  26   1,025  0,856       60
# 2017-05-31T00:42:12.549     76  783  8,6  26   1,024   0,71       60
# 2017-05-31T00:44:04.958     77  783  8,6  26   1,024  0,785       60
# 2017-05-31T00:45:57.400     78  783  8,6  26   1,023  0,708      120
# 2017-05-31T00:48:49.851     79  783  8,6  26   1,022  0,704      120
# 2017-05-31T00:51:42.249     80  783  8,5  26   1,022  0,711       60
# 2017-05-31T00:53:34.704     81  783  8,6  26   1,021  0,719       60
# 2017-05-31T00:55:27.048     82  783  8,8  26   1,021  0,728       60
# 2017-05-31T00:57:20.103     83  783  8,9  25   1,021  0,731      120
# 2017-05-31T01:00:12.403     84  783    9  25   1,021  0,713      120
# 2017-05-31T01:03:04.652     85  783    9  25   1,021  0,638       60
# 2017-05-31T01:04:56.895     86  783    9  25   1,021  0,629       60
# 2017-05-31T01:06:49.302     87  783    9  25   1,021  0,629       60
# ...                        ...  ...  ...  ..     ...    ...      ...
# 2017-05-31T05:05:32.008  data_30may17  reduc_20170530_192.fits
# 2017-05-31T05:07:24.403  data_30may17  reduc_20170530_193.fits
# 2017-05-31T05:10:16.753  data_30may17  reduc_20170530_194.fits
# 2017-05-31T05:13:09.206  data_30may17  reduc_20170530_195.fits
# 2017-05-31T05:15:01.551  data_30may17  reduc_20170530_196.fits
# 2017-05-31T05:16:53.954  data_30may17  reduc_20170530_197.fits
# 2017-05-31T05:18:46.349  data_30may17  reduc_20170530_198.fits
# 2017-05-31T05:21:38.803  data_30may17  reduc_20170530_199.fits
# 2017-05-31T05:56:35.901  data_30may17  reduc_20170530_200.fits
# 2017-05-31T06:05:21.701  data_30may17  reduc_20170530_201.fits
# 2017-05-31T07:03:12.652  data_30may17  reduc_20170530_205.fits
# 2017-05-31T00:00:26.147  data_30may17  reduc_20170530_057.fits
#
# [146 rows x 14 columns]

# %%
bad_obs.sort_values(by="index",inplace=True)

# %%
bad_indexes=bad_obs.loc[:,"index"]

# %%
bad_indexes.index
# Out:
# Index([u'2017-05-31T00:00:26.147', u'2017-05-31T00:00:26.147',
#        u'2017-05-31T00:02:18.596', u'2017-05-31T00:06:14.000',
#        u'2017-05-31T00:08:06.454', u'2017-05-31T00:09:58.852',
#        u'2017-05-31T00:11:51.243', u'2017-05-31T00:14:43.647',
#        u'2017-05-31T00:17:36.001', u'2017-05-31T00:19:28.503',
#        ...
#        u'2017-05-31T05:07:24.403', u'2017-05-31T05:10:16.753',
#        u'2017-05-31T05:13:09.206', u'2017-05-31T05:15:01.551',
#        u'2017-05-31T05:16:53.954', u'2017-05-31T05:18:46.349',
#        u'2017-05-31T05:21:38.803', u'2017-05-31T05:56:35.901',
#        u'2017-05-31T06:05:21.701', u'2017-05-31T07:03:12.652'],
#       dtype='object', name=u'date', length=146)

# %%
bad_indexes.values
# Out:
# array([ 57,  57,  58,  60,  61,  62,  63,  64,  65,  66,  67,  68,  69,
#         70,  71,  72,  73,  74,  75,  76,  77,  78,  79,  80,  81,  82,
#         83,  84,  85,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,
#         96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108,
#        109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121,
#        122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134,
#        135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147,
#        148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160,
#        161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173,
#        174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186,
#        187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199,
#        200, 201, 205])

# %% [markdown]
# - keep stars **HD111980**, **HD205905**

# %%
sel2_obs=sel_obs.loc[sel_obs['object'].isin(['HD205905'])]

# %%
sel2_obs=sel2_obs[sel2_obs.index !=57]      # REMOVE 57

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='object', data=sel2_obs)
plt.grid(True)

# %% [markdown]
# #### Make a list of the object names

# %%
list_of_objects=sel2_obs['object'].values

# %%
list_of_objects=set(list_of_objects)

# %%
list_of_objects=list(list_of_objects)

# %%
list_of_objects_str=','.join(list_of_objects)

# %% [markdown]
# ### find filename for sim spectra

# %%
path_sim1=os.path.join(path_spectrasim,'clearsky')
path_sim2=os.path.join(path_spectrasim,'standard')
path_sim3=os.path.join(path_spectrasim,'merra2')

# %%
search_string=os.path.join(path_sim1,'*.fits')
all_simspectrafiles1=glob.glob(search_string)
all_simspectrafiles1=sorted(all_simspectrafiles1)

# %%
all_simspectrafiles1[:3]
# Out:
# ['../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/clearsky/specsim_20170530_057_spectrum.fits',
#  '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/clearsky/specsim_20170530_058_spectrum.fits',
#  '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/clearsky/specsim_20170530_060_spectrum.fits']

# %%
search_string=os.path.join(path_sim2,'*.fits')
all_simspectrafiles2=glob.glob(search_string)
all_simspectrafiles2=sorted(all_simspectrafiles2)

# %%
all_simspectrafiles2[:3]
# Out:
# ['../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/standard/specsim_20170530_057_spectrum.fits',
#  '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/standard/specsim_20170530_058_spectrum.fits',
#  '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/standard/specsim_20170530_060_spectrum.fits']

# %%
search_string=os.path.join(path_sim3,'*.fits')
all_simspectrafiles3=glob.glob(search_string)
all_simspectrafiles3=sorted(all_simspectrafiles3)

# %%
all_simspectrafiles3[:3]
# Out:
# ['../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/merra2/specsim_20170530_057_spectrum.fits',
#  '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/merra2/specsim_20170530_058_spectrum.fits',
#  '../../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_30may17/merra2/specsim_20170530_060_spectrum.fits']

# %% [markdown]
# # Remove bad indexes

# %%
file_toremove=[]
SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_spectrafiles:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_indexes.values:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_spectrafiles.remove(f)
# Out:
#  remove  reduc_20170530_057_spectrum.fits
#  remove  reduc_20170530_058_spectrum.fits
#  remove  reduc_20170530_060_spectrum.fits
#  remove  reduc_20170530_061_spectrum.fits
#  remove  reduc_20170530_062_spectrum.fits
#  remove  reduc_20170530_063_spectrum.fits
#  remove  reduc_20170530_064_spectrum.fits
#  remove  reduc_20170530_065_spectrum.fits
#  remove  reduc_20170530_066_spectrum.fits
#  remove  reduc_20170530_067_spectrum.fits
#  remove  reduc_20170530_068_spectrum.fits
#  remove  reduc_20170530_069_spectrum.fits
#  remove  reduc_20170530_070_spectrum.fits
#  remove  reduc_20170530_071_spectrum.fits
#  remove  reduc_20170530_072_spectrum.fits
#  remove  reduc_20170530_073_spectrum.fits
#  remove  reduc_20170530_074_spectrum.fits
#  remove  reduc_20170530_075_spectrum.fits
#  remove  reduc_20170530_076_spectrum.fits
#  remove  reduc_20170530_077_spectrum.fits
#  remove  reduc_20170530_078_spectrum.fits
#  remove  reduc_20170530_079_spectrum.fits
#  remove  reduc_20170530_080_spectrum.fits
#  remove  reduc_20170530_081_spectrum.fits
#  remove  reduc_20170530_082_spectrum.fits
#  remove  reduc_20170530_083_spectrum.fits
#  remove  reduc_20170530_084_spectrum.fits
#  remove  reduc_20170530_085_spectrum.fits
#  remove  reduc_20170530_086_spectrum.fits
#  remove  reduc_20170530_087_spectrum.fits
#  remove  reduc_20170530_088_spectrum.fits
#  remove  reduc_20170530_089_spectrum.fits
#  remove  reduc_20170530_090_spectrum.fits
#  remove  reduc_20170530_091_spectrum.fits
#  remove  reduc_20170530_092_spectrum.fits
#  remove  reduc_20170530_093_spectrum.fits
#  remove  reduc_20170530_094_spectrum.fits
#  remove  reduc_20170530_095_spectrum.fits
#  remove  reduc_20170530_096_spectrum.fits
#  remove  reduc_20170530_097_spectrum.fits
#  remove  reduc_20170530_098_spectrum.fits
#  remove  reduc_20170530_099_spectrum.fits
#  remove  reduc_20170530_100_spectrum.fits
#  remove  reduc_20170530_101_spectrum.fits
#  remove  reduc_20170530_102_spectrum.fits
#  remove  reduc_20170530_103_spectrum.fits
#  remove  reduc_20170530_104_spectrum.fits
#  remove  reduc_20170530_105_spectrum.fits
#  remove  reduc_20170530_106_spectrum.fits
#  remove  reduc_20170530_107_spectrum.fits
#  remove  reduc_20170530_108_spectrum.fits
#  remove  reduc_20170530_109_spectrum.fits
#  remove  reduc_20170530_110_spectrum.fits
#  remove  reduc_20170530_111_spectrum.fits
#  remove  reduc_20170530_112_spectrum.fits
#  remove  reduc_20170530_113_spectrum.fits
#  remove  reduc_20170530_114_spectrum.fits
#  remove  reduc_20170530_115_spectrum.fits
#  remove  reduc_20170530_116_spectrum.fits
#  remove  reduc_20170530_117_spectrum.fits
#  remove  reduc_20170530_118_spectrum.fits
#  remove  reduc_20170530_119_spectrum.fits
#  remove  reduc_20170530_120_spectrum.fits
#  remove  reduc_20170530_121_spectrum.fits
#  remove  reduc_20170530_122_spectrum.fits
#  remove  reduc_20170530_123_spectrum.fits
#  remove  reduc_20170530_124_spectrum.fits
#  remove  reduc_20170530_125_spectrum.fits
#  remove  reduc_20170530_126_spectrum.fits
#  remove  reduc_20170530_127_spectrum.fits
#  remove  reduc_20170530_128_spectrum.fits
#  remove  reduc_20170530_129_spectrum.fits
#  remove  reduc_20170530_130_spectrum.fits
#  remove  reduc_20170530_131_spectrum.fits
#  remove  reduc_20170530_132_spectrum.fits
#  remove  reduc_20170530_133_spectrum.fits
#  remove  reduc_20170530_134_spectrum.fits
#  remove  reduc_20170530_135_spectrum.fits
#  remove  reduc_20170530_136_spectrum.fits
#  remove  reduc_20170530_137_spectrum.fits
#  remove  reduc_20170530_138_spectrum.fits
#  remove  reduc_20170530_139_spectrum.fits
#  remove  reduc_20170530_140_spectrum.fits
#  remove  reduc_20170530_141_spectrum.fits
#  remove  reduc_20170530_142_spectrum.fits
#  remove  reduc_20170530_143_spectrum.fits
#  remove  reduc_20170530_144_spectrum.fits
#  remove  reduc_20170530_145_spectrum.fits
#  remove  reduc_20170530_146_spectrum.fits
#  remove  reduc_20170530_147_spectrum.fits
#  remove  reduc_20170530_148_spectrum.fits
#  remove  reduc_20170530_149_spectrum.fits
#  remove  reduc_20170530_150_spectrum.fits
#  remove  reduc_20170530_151_spectrum.fits
#  remove  reduc_20170530_152_spectrum.fits
#  remove  reduc_20170530_153_spectrum.fits
#  remove  reduc_20170530_154_spectrum.fits
#  remove  reduc_20170530_155_spectrum.fits
#  remove  reduc_20170530_156_spectrum.fits
#  remove  reduc_20170530_157_spectrum.fits
#  remove  reduc_20170530_158_spectrum.fits
#  remove  reduc_20170530_159_spectrum.fits
#  remove  reduc_20170530_160_spectrum.fits
#  remove  reduc_20170530_161_spectrum.fits
#  remove  reduc_20170530_162_spectrum.fits
#  remove  reduc_20170530_163_spectrum.fits
#  remove  reduc_20170530_164_spectrum.fits
#  remove  reduc_20170530_165_spectrum.fits
#  remove  reduc_20170530_166_spectrum.fits
#  remove  reduc_20170530_167_spectrum.fits
#  remove  reduc_20170530_168_spectrum.fits
#  remove  reduc_20170530_169_spectrum.fits
#  remove  reduc_20170530_170_spectrum.fits
#  remove  reduc_20170530_171_spectrum.fits
#  remove  reduc_20170530_172_spectrum.fits
#  remove  reduc_20170530_173_spectrum.fits
#  remove  reduc_20170530_174_spectrum.fits
#  remove  reduc_20170530_175_spectrum.fits
#  remove  reduc_20170530_176_spectrum.fits
#  remove  reduc_20170530_177_spectrum.fits
#  remove  reduc_20170530_178_spectrum.fits
#  remove  reduc_20170530_179_spectrum.fits
#  remove  reduc_20170530_180_spectrum.fits
#  remove  reduc_20170530_181_spectrum.fits
#  remove  reduc_20170530_182_spectrum.fits
#  remove  reduc_20170530_183_spectrum.fits
#  remove  reduc_20170530_184_spectrum.fits
#  remove  reduc_20170530_185_spectrum.fits
#  remove  reduc_20170530_186_spectrum.fits
#  remove  reduc_20170530_187_spectrum.fits
#  remove  reduc_20170530_188_spectrum.fits
#  remove  reduc_20170530_189_spectrum.fits
#  remove  reduc_20170530_190_spectrum.fits
#  remove  reduc_20170530_191_spectrum.fits
#  remove  reduc_20170530_192_spectrum.fits
#  remove  reduc_20170530_193_spectrum.fits
#  remove  reduc_20170530_194_spectrum.fits
#  remove  reduc_20170530_195_spectrum.fits
#  remove  reduc_20170530_196_spectrum.fits
#  remove  reduc_20170530_197_spectrum.fits
#  remove  reduc_20170530_198_spectrum.fits
#  remove  reduc_20170530_199_spectrum.fits
#  remove  reduc_20170530_200_spectrum.fits
#  remove  reduc_20170530_201_spectrum.fits
#  remove  reduc_20170530_205_spectrum.fits

# %%
file_toremove=[]
SelectTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_simspectrafiles1:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_indexes.values:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_simspectrafiles1.remove(f)
# Out:
#  remove  specsim_20170530_057_spectrum.fits
#  remove  specsim_20170530_058_spectrum.fits
#  remove  specsim_20170530_060_spectrum.fits
#  remove  specsim_20170530_061_spectrum.fits
#  remove  specsim_20170530_062_spectrum.fits
#  remove  specsim_20170530_063_spectrum.fits
#  remove  specsim_20170530_064_spectrum.fits
#  remove  specsim_20170530_065_spectrum.fits
#  remove  specsim_20170530_066_spectrum.fits
#  remove  specsim_20170530_067_spectrum.fits
#  remove  specsim_20170530_068_spectrum.fits
#  remove  specsim_20170530_069_spectrum.fits
#  remove  specsim_20170530_070_spectrum.fits
#  remove  specsim_20170530_071_spectrum.fits
#  remove  specsim_20170530_072_spectrum.fits
#  remove  specsim_20170530_073_spectrum.fits
#  remove  specsim_20170530_074_spectrum.fits
#  remove  specsim_20170530_075_spectrum.fits
#  remove  specsim_20170530_076_spectrum.fits
#  remove  specsim_20170530_077_spectrum.fits
#  remove  specsim_20170530_078_spectrum.fits
#  remove  specsim_20170530_079_spectrum.fits
#  remove  specsim_20170530_080_spectrum.fits
#  remove  specsim_20170530_081_spectrum.fits
#  remove  specsim_20170530_082_spectrum.fits
#  remove  specsim_20170530_083_spectrum.fits
#  remove  specsim_20170530_084_spectrum.fits
#  remove  specsim_20170530_085_spectrum.fits
#  remove  specsim_20170530_086_spectrum.fits
#  remove  specsim_20170530_087_spectrum.fits
#  remove  specsim_20170530_088_spectrum.fits
#  remove  specsim_20170530_089_spectrum.fits
#  remove  specsim_20170530_090_spectrum.fits
#  remove  specsim_20170530_091_spectrum.fits
#  remove  specsim_20170530_092_spectrum.fits
#  remove  specsim_20170530_093_spectrum.fits
#  remove  specsim_20170530_094_spectrum.fits
#  remove  specsim_20170530_095_spectrum.fits
#  remove  specsim_20170530_096_spectrum.fits
#  remove  specsim_20170530_097_spectrum.fits
#  remove  specsim_20170530_098_spectrum.fits
#  remove  specsim_20170530_099_spectrum.fits
#  remove  specsim_20170530_167_spectrum.fits
#  remove  specsim_20170530_168_spectrum.fits
#  remove  specsim_20170530_169_spectrum.fits
#  remove  specsim_20170530_170_spectrum.fits
#  remove  specsim_20170530_171_spectrum.fits
#  remove  specsim_20170530_172_spectrum.fits
#  remove  specsim_20170530_173_spectrum.fits
#  remove  specsim_20170530_174_spectrum.fits
#  remove  specsim_20170530_175_spectrum.fits
#  remove  specsim_20170530_176_spectrum.fits
#  remove  specsim_20170530_177_spectrum.fits
#  remove  specsim_20170530_178_spectrum.fits
#  remove  specsim_20170530_179_spectrum.fits
#  remove  specsim_20170530_180_spectrum.fits
#  remove  specsim_20170530_181_spectrum.fits
#  remove  specsim_20170530_182_spectrum.fits
#  remove  specsim_20170530_183_spectrum.fits
#  remove  specsim_20170530_184_spectrum.fits
#  remove  specsim_20170530_185_spectrum.fits
#  remove  specsim_20170530_186_spectrum.fits
#  remove  specsim_20170530_187_spectrum.fits
#  remove  specsim_20170530_188_spectrum.fits
#  remove  specsim_20170530_189_spectrum.fits
#  remove  specsim_20170530_190_spectrum.fits
#  remove  specsim_20170530_191_spectrum.fits
#  remove  specsim_20170530_192_spectrum.fits
#  remove  specsim_20170530_193_spectrum.fits
#  remove  specsim_20170530_194_spectrum.fits
#  remove  specsim_20170530_195_spectrum.fits
#  remove  specsim_20170530_196_spectrum.fits
#  remove  specsim_20170530_197_spectrum.fits
#  remove  specsim_20170530_198_spectrum.fits
#  remove  specsim_20170530_199_spectrum.fits
#  remove  specsim_20170530_200_spectrum.fits
#  remove  specsim_20170530_201_spectrum.fits
#  remove  specsim_20170530_205_spectrum.fits

# %%
file_toremove=[]
SelectTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_simspectrafiles2:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_indexes.values:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_simspectrafiles2.remove(f)
# Out:
#  remove  specsim_20170530_057_spectrum.fits
#  remove  specsim_20170530_058_spectrum.fits
#  remove  specsim_20170530_060_spectrum.fits
#  remove  specsim_20170530_061_spectrum.fits
#  remove  specsim_20170530_062_spectrum.fits
#  remove  specsim_20170530_063_spectrum.fits
#  remove  specsim_20170530_064_spectrum.fits
#  remove  specsim_20170530_065_spectrum.fits
#  remove  specsim_20170530_066_spectrum.fits
#  remove  specsim_20170530_067_spectrum.fits
#  remove  specsim_20170530_068_spectrum.fits
#  remove  specsim_20170530_069_spectrum.fits
#  remove  specsim_20170530_070_spectrum.fits
#  remove  specsim_20170530_071_spectrum.fits
#  remove  specsim_20170530_072_spectrum.fits
#  remove  specsim_20170530_073_spectrum.fits
#  remove  specsim_20170530_074_spectrum.fits
#  remove  specsim_20170530_075_spectrum.fits
#  remove  specsim_20170530_076_spectrum.fits
#  remove  specsim_20170530_077_spectrum.fits
#  remove  specsim_20170530_078_spectrum.fits
#  remove  specsim_20170530_079_spectrum.fits
#  remove  specsim_20170530_080_spectrum.fits
#  remove  specsim_20170530_081_spectrum.fits
#  remove  specsim_20170530_082_spectrum.fits
#  remove  specsim_20170530_083_spectrum.fits
#  remove  specsim_20170530_084_spectrum.fits
#  remove  specsim_20170530_085_spectrum.fits
#  remove  specsim_20170530_086_spectrum.fits
#  remove  specsim_20170530_153_spectrum.fits
#  remove  specsim_20170530_154_spectrum.fits
#  remove  specsim_20170530_155_spectrum.fits
#  remove  specsim_20170530_156_spectrum.fits
#  remove  specsim_20170530_157_spectrum.fits
#  remove  specsim_20170530_158_spectrum.fits
#  remove  specsim_20170530_159_spectrum.fits
#  remove  specsim_20170530_160_spectrum.fits
#  remove  specsim_20170530_161_spectrum.fits
#  remove  specsim_20170530_162_spectrum.fits
#  remove  specsim_20170530_163_spectrum.fits
#  remove  specsim_20170530_164_spectrum.fits
#  remove  specsim_20170530_165_spectrum.fits
#  remove  specsim_20170530_166_spectrum.fits
#  remove  specsim_20170530_167_spectrum.fits
#  remove  specsim_20170530_168_spectrum.fits
#  remove  specsim_20170530_169_spectrum.fits
#  remove  specsim_20170530_170_spectrum.fits
#  remove  specsim_20170530_171_spectrum.fits
#  remove  specsim_20170530_172_spectrum.fits
#  remove  specsim_20170530_173_spectrum.fits
#  remove  specsim_20170530_174_spectrum.fits
#  remove  specsim_20170530_175_spectrum.fits
#  remove  specsim_20170530_176_spectrum.fits
#  remove  specsim_20170530_177_spectrum.fits
#  remove  specsim_20170530_178_spectrum.fits
#  remove  specsim_20170530_179_spectrum.fits
#  remove  specsim_20170530_180_spectrum.fits
#  remove  specsim_20170530_181_spectrum.fits
#  remove  specsim_20170530_182_spectrum.fits
#  remove  specsim_20170530_183_spectrum.fits
#  remove  specsim_20170530_184_spectrum.fits
#  remove  specsim_20170530_185_spectrum.fits
#  remove  specsim_20170530_186_spectrum.fits
#  remove  specsim_20170530_187_spectrum.fits
#  remove  specsim_20170530_188_spectrum.fits
#  remove  specsim_20170530_189_spectrum.fits
#  remove  specsim_20170530_190_spectrum.fits
#  remove  specsim_20170530_191_spectrum.fits
#  remove  specsim_20170530_192_spectrum.fits
#  remove  specsim_20170530_193_spectrum.fits
#  remove  specsim_20170530_194_spectrum.fits
#  remove  specsim_20170530_195_spectrum.fits
#  remove  specsim_20170530_196_spectrum.fits
#  remove  specsim_20170530_197_spectrum.fits
#  remove  specsim_20170530_198_spectrum.fits
#  remove  specsim_20170530_199_spectrum.fits
#  remove  specsim_20170530_200_spectrum.fits
#  remove  specsim_20170530_201_spectrum.fits
#  remove  specsim_20170530_205_spectrum.fits

# %%
file_toremove=[]
SelectTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_simspectrafiles3:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_indexes.values:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_simspectrafiles3.remove(f)
# Out:
#  remove  specsim_20170530_057_spectrum.fits
#  remove  specsim_20170530_058_spectrum.fits
#  remove  specsim_20170530_060_spectrum.fits
#  remove  specsim_20170530_061_spectrum.fits
#  remove  specsim_20170530_062_spectrum.fits
#  remove  specsim_20170530_063_spectrum.fits
#  remove  specsim_20170530_064_spectrum.fits
#  remove  specsim_20170530_065_spectrum.fits
#  remove  specsim_20170530_066_spectrum.fits
#  remove  specsim_20170530_067_spectrum.fits
#  remove  specsim_20170530_068_spectrum.fits
#  remove  specsim_20170530_069_spectrum.fits
#  remove  specsim_20170530_070_spectrum.fits
#  remove  specsim_20170530_071_spectrum.fits
#  remove  specsim_20170530_072_spectrum.fits
#  remove  specsim_20170530_073_spectrum.fits
#  remove  specsim_20170530_140_spectrum.fits
#  remove  specsim_20170530_141_spectrum.fits
#  remove  specsim_20170530_142_spectrum.fits
#  remove  specsim_20170530_143_spectrum.fits
#  remove  specsim_20170530_144_spectrum.fits
#  remove  specsim_20170530_145_spectrum.fits
#  remove  specsim_20170530_146_spectrum.fits
#  remove  specsim_20170530_147_spectrum.fits
#  remove  specsim_20170530_148_spectrum.fits
#  remove  specsim_20170530_149_spectrum.fits
#  remove  specsim_20170530_150_spectrum.fits
#  remove  specsim_20170530_151_spectrum.fits
#  remove  specsim_20170530_152_spectrum.fits
#  remove  specsim_20170530_153_spectrum.fits
#  remove  specsim_20170530_154_spectrum.fits
#  remove  specsim_20170530_155_spectrum.fits
#  remove  specsim_20170530_156_spectrum.fits
#  remove  specsim_20170530_157_spectrum.fits
#  remove  specsim_20170530_158_spectrum.fits
#  remove  specsim_20170530_159_spectrum.fits
#  remove  specsim_20170530_160_spectrum.fits
#  remove  specsim_20170530_161_spectrum.fits
#  remove  specsim_20170530_162_spectrum.fits
#  remove  specsim_20170530_163_spectrum.fits
#  remove  specsim_20170530_164_spectrum.fits
#  remove  specsim_20170530_165_spectrum.fits
#  remove  specsim_20170530_166_spectrum.fits
#  remove  specsim_20170530_167_spectrum.fits
#  remove  specsim_20170530_168_spectrum.fits
#  remove  specsim_20170530_169_spectrum.fits
#  remove  specsim_20170530_170_spectrum.fits
#  remove  specsim_20170530_171_spectrum.fits
#  remove  specsim_20170530_172_spectrum.fits
#  remove  specsim_20170530_173_spectrum.fits
#  remove  specsim_20170530_174_spectrum.fits
#  remove  specsim_20170530_175_spectrum.fits
#  remove  specsim_20170530_176_spectrum.fits
#  remove  specsim_20170530_177_spectrum.fits
#  remove  specsim_20170530_178_spectrum.fits
#  remove  specsim_20170530_179_spectrum.fits
#  remove  specsim_20170530_180_spectrum.fits
#  remove  specsim_20170530_181_spectrum.fits
#  remove  specsim_20170530_182_spectrum.fits
#  remove  specsim_20170530_183_spectrum.fits
#  remove  specsim_20170530_184_spectrum.fits
#  remove  specsim_20170530_185_spectrum.fits
#  remove  specsim_20170530_186_spectrum.fits
#  remove  specsim_20170530_187_spectrum.fits
#  remove  specsim_20170530_188_spectrum.fits
#  remove  specsim_20170530_189_spectrum.fits
#  remove  specsim_20170530_190_spectrum.fits
#  remove  specsim_20170530_191_spectrum.fits
#  remove  specsim_20170530_192_spectrum.fits
#  remove  specsim_20170530_193_spectrum.fits
#  remove  specsim_20170530_194_spectrum.fits
#  remove  specsim_20170530_195_spectrum.fits
#  remove  specsim_20170530_196_spectrum.fits
#  remove  specsim_20170530_197_spectrum.fits
#  remove  specsim_20170530_198_spectrum.fits
#  remove  specsim_20170530_199_spectrum.fits
#  remove  specsim_20170530_200_spectrum.fits
#  remove  specsim_20170530_201_spectrum.fits
#  remove  specsim_20170530_205_spectrum.fits

# %% [markdown]
# # which filters

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='filter', data=sel2_obs)
plt.grid(True)

# %% [markdown]
# # which are the dispersers ?

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='disperser', data=sel2_obs)
plt.grid(True)

# %%
sel_obs_Ron400=sel2_obs.loc[sel2_obs['disperser'].isin(['Ron400'])]

# %%
sel_obs_Thor300=sel2_obs.loc[sel2_obs['disperser'].isin(['Thor300'])]

# %%
sel_obs_HoloPhP=sel2_obs.loc[sel2_obs['disperser'].isin(['HoloPhP'])]

# %%
sel_obs_HoloPhAg=sel2_obs.loc[sel2_obs['disperser'].isin(['HoloPhAg'])]

# %%
sel_obs_HoloAmAg=sel2_obs.loc[sel2_obs['disperser'].isin(['HoloAmAg'])]

# %% [markdown]
# # Show the spectra

# %%
def PlotSpectra(the_filelist,the_obs,the_searchtag,the_title,Flag_corr_wl=False):
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser
    
    plt.figure(figsize=(10,8))
    for the_file in the_filelist:
        idx=get_index_from_filename(the_file,the_searchtag)
        if idx in the_selected_indexes:
            if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
            else:
                time_correction=0
            
            hdu = fits.open(the_file)
            data=hdu[0].data
            wl=data[0]+time_correction
            fl=data[1]
            plt.plot(wl,fl)
    plt.grid()    
    plt.title(the_title)
    plt.xlabel("$\lambda$ (nm)")

# %% [markdown]
# ## Show the reconstructed spectra

# %%
SearchTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
print SearchTagRe
# Out:
# ^reduc_20170530_([0-9]+)_spectrum.fits$

# %% [markdown]
# ### Ronchi 400 spectra

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Ronchi400"

# %%
PlotSpectra(all_spectrafiles,sel_obs_Ron400,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### Thor 300

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Thor300"

# %%
PlotSpectra(all_spectrafiles,sel_obs_Thor300,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### HoloPhP

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhP"

# %%
PlotSpectra(all_spectrafiles,sel_obs_HoloPhP,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### HoloPhAg

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhAg"

# %%
PlotSpectra(all_spectrafiles,sel_obs_HoloPhAg,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### HoloAmAg

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloAmAg"

# %%
PlotSpectra(all_spectrafiles,sel_obs_HoloAmAg,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ## Show the simulated spectra

# %%
SearchTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)

# %% [markdown]
# ### Clear sky

# %%
thetitle="sim spectra for night (clearsky) "+All_Subdirs[idx_sel_subdir]+' target :'+list_of_objects_str

# %%
PlotSpectra(all_simspectrafiles1,sel2_obs,SearchTagRe,thetitle)

# %% [markdown]
# ### standard sky

# %%
thetitle="sim spectra for night (standard) "+All_Subdirs[idx_sel_subdir]+' target :'+list_of_objects_str

# %%
PlotSpectra(all_simspectrafiles2,sel2_obs,SearchTagRe,thetitle)

# %% [markdown]
# ### merra2 sky

# %%
thetitle="sim spectra for night (merra2) "+All_Subdirs[idx_sel_subdir]+' target :'+list_of_objects_str

# %%
PlotSpectra(all_simspectrafiles3,sel2_obs,SearchTagRe,thetitle)

# %% [markdown]
# # Spectra ratio data/sim

# %%
def PlotSpectraRatio(the_filelist,path_tosims,the_obs,the_searchtag,the_title,Flag_corr_wl=False,XMIN=400,XMAX=1000.):
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser
    
    plt.figure(figsize=(10,8))
    for the_file in the_filelist:  # loop on reconstruted spectra
        idx=get_index_from_filename(the_file,the_searchtag)
        if idx in the_selected_indexes:   
            
            if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
            else:
                time_correction=0
            
            
            # check if tthe index is in the disperser indexes 
            basefn=os.path.basename(the_file)                  # basename of reconstruced spectra
            basefn2=basefn.replace('reduc','specsim')  # reconstruct the simulation filename
            the_filesim=os.path.join(path_tosims,basefn2)  # add the path for the simulated file
            
            hdu1 = fits.open(the_file)
            data1=hdu1[0].data
            wl1=data1[0]+time_correction
            fl1=data1[1]
            
            # extend range for (wl1,fl1)
            wl1=np.insert(wl1,0,WL[0])
            fl1=np.insert(fl1,0,0.)
            
            wl1=np.append(wl1,WL[-1])
            fl1=np.append(fl1,0.)
            
            hdu2 = fits.open(the_filesim)
            data2=hdu2[0].data
            wl2=data2[0]
            fl2=data2[1]
            
            func = interpolate.interp1d(wl1, fl1)
            fl0=func(WL)
            
            plt.plot(WL,fl0/fl2)
    plt.xlim(XMIN,XMAX)
    plt.grid()    
    plt.title(the_title)
    plt.xlabel("$\lambda$ (nm)")   
    plt.ylabel("spectra ratio")

# %%
def PlotSpectraLogRatio(the_filelist,path_tosims,the_obs,the_searchtag,the_title,Flag_corr_wl=False,XMIN=400,XMAX=1000.):
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser
    
    plt.figure(figsize=(10,8))
    for the_file in the_filelist:  # loop on reconstruted spectra
        idx=get_index_from_filename(the_file,the_searchtag)
        
        if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
        else:
                time_correction=0
        
        
        if idx in the_selected_indexes:                # check if tthe index is in the disperser indexes 
            basefn=os.path.basename(the_file)                  # basename of reconstruced spectra
            basefn2=basefn.replace('reduc','specsim')  # reconstruct the simulation filename
            the_filesim=os.path.join(path_tosims,basefn2)  # add the path for the simulated file
            
            hdu1 = fits.open(the_file)
            data1=hdu1[0].data
            wl1=data1[0]+time_correction
            fl1=data1[1]
            
            # extend range for (wl1,fl1)
            wl1=np.insert(wl1,0,WL[0])
            fl1=np.insert(fl1,0,0.)
            
            wl1=np.append(wl1,WL[-1])
            fl1=np.append(fl1,0.)
            
            hdu2 = fits.open(the_filesim)
            data2=hdu2[0].data
            wl2=data2[0]
            fl2=data2[1]
            
            func = interpolate.interp1d(wl1, fl1)
            fl0=func(WL)
            
            plt.plot(WL,2.5*(np.log10(fl0)-np.log10(fl2)))
    plt.xlim(XMIN,XMAX)
    plt.grid()    
    plt.title(the_title)
    plt.xlabel("$\lambda$ (nm)")  
    plt.ylabel("log of spectra ratio (mag)")

# %%
def SaveSpectraRatio(the_filelist,path_tosims,the_obs,the_searchtag,the_ratio_file,Flag_corr_wl=False):
    
    all_ratio_arr=np.zeros((1,len(WL)))
    all_ratio_arr[0,:]=WL
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser    
    for the_file in the_filelist:  # loop on reconstruted spectra
        idx=get_index_from_filename(the_file,the_searchtag)
        if idx in the_selected_indexes:                # check if tthe index is in the disperser indexes 
            
            
            if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
            else:
                time_correction=0
            
            
            basefn=os.path.basename(the_file)                  # basename of reconstruced spectra
            basefn2=basefn.replace('reduc','specsim')  # reconstruct the simulation filename
            the_filesim=os.path.join(path_tosims,basefn2)  # add the path for the simulated file
            
            hdu1 = fits.open(the_file)
            header1=data1=hdu1[0].header
            airmass=header1["airmass"]
            target=header1["target"]
            
            data1=hdu1[0].data
            wl1=data1[0]+time_correction
            fl1=data1[1]
            
            # extend range for (wl1,fl1)
            wl1=np.insert(wl1,0,WL[0])
            fl1=np.insert(fl1,0,0.)
            
            wl1=np.append(wl1,WL[-1])
            fl1=np.append(fl1,0.)
            
            hdu2 = fits.open(the_filesim)
            data2=hdu2[0].data
            wl2=data2[0]
            fl2=data2[1]
            
            func = interpolate.interp1d(wl1, fl1)
            fl0=func(WL)
            ratio=fl0/fl2
            new_ratio=np.expand_dims(ratio, axis=0)
            all_ratio_arr=np.append(all_ratio_arr,new_ratio,axis=0)
            
            
    hdu = fits.PrimaryHDU(all_ratio_arr)
    hdul = fits.HDUList([hdu])
    hdul.writeto(the_ratio_file,overwrite=True)
    
    return all_ratio_arr

# %%
SearchTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)

# %% [markdown]
# ## spectra ratio for Ronchi 400

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Ronchi400"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_Ron400,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_Ron400,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_Ron400,SearchTagRe,"ratio_Ron400.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %%
plt.imshow(arr[1:,:],cmap='jet')

# %% [markdown]
# ## spectra ratio for Thor300

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Thor300"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim1,sel_obs_Thor300,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_Thor300,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_Thor300,SearchTagRe,"ratio_Thor300.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## spectra ratio for HoloPhP

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhP"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhP,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhP,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhP,SearchTagRe,"ratio_HoloPhP.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## Spectrum ratio for HoloPhAg

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhAg"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in log10

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhAg,SearchTagRe,"ratio_HoloPhAg.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## Spectrum ratio for HoloAmAg

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloAmAg"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloAmAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_HoloAmAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloAmAg,SearchTagRe,"ratio_HoloAmAg.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %%
# !ls *.fits
# Out:
# ratio_HoloAmAg.fits ratio_HoloPhP.fits  ratio_Thor300.fits
# ratio_HoloPhAg.fits ratio_Ron400.fits
