# %% [markdown]
# # Disperser transmission study
#
#
# Study the true transmission wrt transmission in simulatio
#
# - author Sylvie Dagoret-Campagne
# - creation date : May 2018
# - affliliation : CNRS/IN2P3
# - project : DESC-LSST

# %% [markdown]
# - need to increase the number of files to be open:
#
#     ulimit -a
#
#     ulimit -n 2048
#
#     ulimit -Sn 10000

# %%
# !ulimit -a
# Out:
# core file size          (blocks, -c) 0
# data seg size           (kbytes, -d) unlimited
# file size               (blocks, -f) unlimited
# max locked memory       (kbytes, -l) unlimited
# max memory size         (kbytes, -m) unlimited
# open files                      (-n) 2048
# pipe size            (512 bytes, -p) 1
# stack size              (kbytes, -s) 8192
# cpu time               (seconds, -t) unlimited
# max user processes              (-u) 1418
# virtual memory          (kbytes, -v) unlimited

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Notebook style

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width: 90%;
# /*        margin-left:auto;*/
# /*        margin-right:auto;*/
#     }
#     ul {
#         line-height: 145%;
#         font-size: 90%;
#     }
#     li {
#         margin-bottom: 1em;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top: 12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# ### import

# %%
import matplotlib.pyplot as plt
import sys
import os
import pandas as pd
import glob
from matplotlib.backends.backend_pdf import PdfPages

# %%
from scipy import interpolate

# %%
import seaborn as sns

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Figure style

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 10),   #defines the default image size
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
plt.rcParams.update({'figure.max_open_warning': 0}) # to see a large number of files

# %% [markdown]
# ## Initialisation

# %% [markdown]
# ### Spectractor

# %%
PATH_SPECTRACTOR='../../Spectractor'
PATH_SPECTRACTORSIM='../../SpectractorSim'
PATH_SPECTRACTORANAATM='../../SpectractorAnaAtm/common_tools'
PATH_GMAOMERRA='../merra2'

# %%
sys.path.append(PATH_SPECTRACTOR)
sys.path.append(PATH_SPECTRACTORSIM)
sys.path.append(PATH_SPECTRACTORANAATM)
sys.path.append(PATH_GMAOMERRA)

# %%
from spectractor import *
from spectractorsim import *
from libspecana import *

# %% [markdown]
# ## Input spectra

# %% [markdown]
# ### LogBook

# %%
file_logbook_csv=os.path.join(PATH_SPECTRACTOR,'ctiofulllogbook_jun2017_v4.csv')

# %%
df_ctio_lbk=pd.read_csv(file_logbook_csv,sep=';')

# %%
df_ctio_lbk.columns
# Out:
# Index([u'Unnamed: 0', u'date', u'subdir', u'index', u'object', u'filter',
#        u'disperser', u'airmass', u'exposure', u'focus', u'seeing', u'P', u'T',
#        u'RH', u'W', u'file', u'Obj-posXpix', u'Obj-posYpix', u'Dx', u'Dy',
#        u'comment', u'skip'],
#       dtype='object')

# %%
df_ctio_lbk=df_ctio_lbk.reindex(columns=['date','index','P','T','RH','airmass','seeing','exposure','object','filter','disperser','focus','W','subdir','file']).set_index('date').sort_index()

# %% [markdown]
# ### Spectra Data

# %%
home=os.getenv('HOME')

# %%
path_data=os.path.join(home,'DATA/CTIODataJune2017_reduced_RG715_v2_prod1')
#path_data=os.path.join('/sps/lsst/data/AtmosphericCalibration','CTIODataJune2017_reduced_RG715_v2_prod1')

# %%
All_Subdirs=np.array(['data_28may17','data_29may17','data_30may17','data_31may17','data_01jun17','data_02jun17',
            'data_03jun17','data_04jun17','data_06jun17','data_08jun17','data_09jun17','data_10jun17',
            'data_12jun17','data_13jun17'])

# %%
Flag_Photometric_Nights=np.array([False,False,True,False,False,False,False,False,False,True,False,True,True,False])

# %%
photometric_indexes=np.where(Flag_Photometric_Nights)[0]

# %%
print 'Photometric indexes : ',photometric_indexes
# Out:
# Photometric indexes :  [ 2  9 11 12]

# %%
print 'Photometric nights : ',All_Subdirs[photometric_indexes]
# Out:
# Photometric nights :  ['data_30may17' 'data_08jun17' 'data_10jun17' 'data_12jun17']

# %% [markdown]
# ### Sim spectra

# %%
PATH_SPECTRACTORSIM
# Out:
# '../../SpectractorSim'

# %%
path_sim=os.path.join(PATH_SPECTRACTORSIM,'sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra')
#path_sim=PATH_SPECTRACTORSIM+'/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra'

# %%
path_sim
# Out:
# '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra'

# %% [markdown]
# ## Selection of night

# %%
date="20170608"

# %%
idx_sel_subdir=9

# %%
SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)

# %% [markdown]
# ### Logbook

# %%
all_obs=df_ctio_lbk.loc[(df_ctio_lbk["subdir"]==All_Subdirs[idx_sel_subdir])].sort_index()

# %%
all_obs_extr=all_obs[["index","object"]]

# %% [markdown]
# ### Wavelength correction

# %%
FLAG_WL_CORRECTION=True # specify if correction on wavelength can be performed from input file
file_wavelengthshift="wavelength_shift.csv"
wlshift=pd.read_csv(file_wavelengthshift)

# %%
wlshift.head()
# Out:
#    index    wlshift
# 0      4   0.000000
# 1      5   1.960594
# 2      7   1.156425
# 3      8   0.000000
# 4      9 -28.924581

# %% [markdown]
# ### path for spectra

# %%
path_spectra=os.path.join(path_data,All_Subdirs[idx_sel_subdir])
path_spectrasim=os.path.join(path_sim,All_Subdirs[idx_sel_subdir])

# %% [markdown]
# ### find filename for data spectra

# %%
search_string=os.path.join(path_spectra,'*.fits')
all_spectrafiles=glob.glob(search_string)
all_spectrafiles=sorted(all_spectrafiles)

# %% [markdown]
# ### extract the index from the data spectra filename

# %%
#SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
all_sel_indexes=[]
for ffn in all_spectrafiles:
    all_sel_indexes.append(get_index_from_filename(ffn,SelectTagRe))
all_sel_indexes=np.array(all_sel_indexes)

# %% [markdown]
# ### extract the logbook rows corrsponding to the spectra
#
# - use the indexes obtained to extract the relevant rows from the logbook

# %%
sel_obs=all_obs.loc[all_obs['index'].isin(all_sel_indexes)]

# %%
sel_obs.head()
# Out:
#                          index    P    T  RH airmass seeing exposure  \
# date
# 2017-06-09T00:23:03.951      4  784  5,6   0   1,021  0,962       60
# 2017-06-09T00:24:57.006      5  784  5,6   0   1,021  0,962       60
# 2017-06-09T00:26:53.450      6  784  5,5   0   1,021  0,962       60
# 2017-06-09T00:28:47.905      7  784  5,5   0   1,021  0,962       60
# 2017-06-09T00:30:44.403      8  784  5,5   0   1,021  0,962       60
#
#                            object filter disperser  focus     W        subdir  \
# date
# 2017-06-09T00:23:03.951  HD111980  FGB37    Ron200  12450  15,2  data_08jun17
# 2017-06-09T00:24:57.006  HD111980  RG715    Ron200  12450  14,5  data_08jun17
# 2017-06-09T00:26:53.450  HD111980  FGB37   Thor300  12450  14,2  data_08jun17
# 2017-06-09T00:28:47.905  HD111980  RG715   Thor300  12450    13  data_08jun17
# 2017-06-09T00:30:44.403  HD111980  FGB37   HoloPhP  12450  14,7  data_08jun17
#
#                                             file
# date
# 2017-06-09T00:23:03.951  reduc_20170608_004.fits
# 2017-06-09T00:24:57.006  reduc_20170608_005.fits
# 2017-06-09T00:26:53.450  reduc_20170608_006.fits
# 2017-06-09T00:28:47.905  reduc_20170608_007.fits
# 2017-06-09T00:30:44.403  reduc_20170608_008.fits

# %%
sel_obs.tail()
# Out:
#                          index    P    T  RH airmass seeing exposure  \
# date
# 2017-06-09T10:32:32.106    353  783  8,6  31   1,051  0,962       30
# 2017-06-09T10:33:58.007    354  783  8,6  35   1,053  0,962       15
# 2017-06-09T10:35:07.405    355  783  8,6   0   1,055  0,962       15
# 2017-06-09T10:36:16.849    356  783  8,7   0   1,056  0,962       15
# 2017-06-09T10:37:26.304    357  783  8,6   0   1,058  0,962       15
#
#                            object filter disperser  focus     W        subdir  \
# date
# 2017-06-09T10:32:32.106  HD205905  RG715  HoloAmAg  12450   9,6  data_08jun17
# 2017-06-09T10:33:58.007  HD205905  FGB37    Ron200  12450     7  data_08jun17
# 2017-06-09T10:35:07.405  HD205905  RG715    Ron200  12450   6,5  data_08jun17
# 2017-06-09T10:36:16.849  HD205905  FGB37   Thor300  12450  13,4  data_08jun17
# 2017-06-09T10:37:26.304  HD205905  RG715   Thor300  12450   7,6  data_08jun17
#
#                                             file
# date
# 2017-06-09T10:32:32.106  reduc_20170608_353.fits
# 2017-06-09T10:33:58.007  reduc_20170608_354.fits
# 2017-06-09T10:35:07.405  reduc_20170608_355.fits
# 2017-06-09T10:36:16.849  reduc_20170608_356.fits
# 2017-06-09T10:37:26.304  reduc_20170608_357.fits

# %% [markdown]
# ### Quick view on the kind of sources

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='object', data=sel_obs)
plt.grid(True)

# %%
plt.figure(figsize=(5,3))
sel_obs['object'].value_counts().plot(kind='bar',rot=0)
plt.xticks(rotation=-45)
plt.grid(True)

# %% [markdown]
# ### Remove bad sources
#
# - remove star **PNG336.3-05.6**

# %%
bad_obs=sel_obs.loc[sel_obs['object'].isin(['PNG336.3-05.6'])]
bad_indexes=bad_obs["index"]

# %%
bad_obs
# Out:
# Empty DataFrame
# Columns: [index, P, T, RH, airmass, seeing, exposure, object, filter, disperser, focus, W, subdir, file]
# Index: []

# %%
bad_indexes=bad_obs.loc[:,"index"]

# %%
bad_indexes.index
# Out:
# Index([], dtype='object', name=u'date')

# %%
bad_indexes.values
# Out:
# array([], dtype=int64)

# %% [markdown]
# - keep stars **HD111980**, **HD205905**

# %%
sel2_obs=sel_obs.loc[sel_obs['object'].isin(['HD111980','HD205905'])]

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='object', data=sel2_obs)
plt.grid(True)

# %% [markdown]
# ### Bad indexes

# %% [markdown]
# #### Make a list of the object names

# %%
list_of_objects=sel2_obs['object'].values

# %%
list_of_objects=set(list_of_objects)

# %%
list_of_objects=list(list_of_objects)

# %%
list_of_objects_str=','.join(list_of_objects)

# %% [markdown]
# # Remove bad indexes

# %%
bad_calib_indexes=np.array([6,16,23,26,36,46,56,66,76,86,96,106,116])

# %%
all_spectrafiles
# Out:
# ['/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_004_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_005_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_006_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_007_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_008_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_009_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_010_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_011_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_012_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_013_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_014_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_015_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_016_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_017_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_018_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_019_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_020_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_021_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_022_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_023_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_024_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_025_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_026_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_027_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_028_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_029_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_030_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_031_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_032_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_033_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_034_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_035_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_036_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_037_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_038_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_039_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_040_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_041_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_042_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_043_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_044_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_045_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_046_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_047_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_048_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_049_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_050_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_051_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_052_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_053_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_054_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_055_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_056_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_057_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_058_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_059_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_060_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_061_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_062_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_063_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_064_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_065_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_066_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_067_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_068_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_069_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_070_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_071_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_072_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_073_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_074_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_075_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_076_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_077_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_078_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_079_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_080_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_081_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_082_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_083_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_084_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_085_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_086_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_087_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_088_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_089_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_090_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_091_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_092_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_093_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_094_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_095_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_096_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_097_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_098_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_099_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_100_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_101_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_102_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_103_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_104_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_105_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_106_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_107_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_108_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_109_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_110_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_111_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_112_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_113_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_114_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_115_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_116_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_144_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_145_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_146_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_147_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_148_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_149_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_150_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_151_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_152_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_153_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_154_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_155_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_156_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_157_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_158_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_159_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_160_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_161_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_162_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_163_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_164_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_165_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_166_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_167_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_168_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_169_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_170_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_171_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_172_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_173_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_174_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_175_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_176_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_177_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_178_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_179_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_180_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_181_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_182_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_183_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_184_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_185_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_186_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_187_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_188_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_189_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_190_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_191_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_192_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_193_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_194_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_195_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_196_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_197_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_198_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_199_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_200_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_201_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_202_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_203_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_204_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_205_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_206_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_207_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_208_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_209_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_210_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_211_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_212_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_213_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_214_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_215_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_216_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_217_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_218_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_219_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_220_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_221_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_222_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_223_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_224_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_225_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_226_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_227_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_228_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_229_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_230_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_231_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_232_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_233_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_234_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_235_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_236_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_237_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_238_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_239_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_240_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_241_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_242_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_243_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_244_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_245_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_246_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_247_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_248_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_249_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_250_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_251_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_252_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_253_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_254_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_255_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_256_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_257_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_258_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_259_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_260_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_261_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_262_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_263_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_264_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_265_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_266_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_267_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_268_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_269_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_270_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_271_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_272_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_273_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_274_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_275_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_276_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_277_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_278_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_279_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_280_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_281_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_282_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_283_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_284_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_285_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_286_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_287_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_288_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_289_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_290_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_291_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_292_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_293_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_294_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_295_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_296_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_297_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_298_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_299_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_300_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_301_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_302_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_303_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_304_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_305_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_306_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_307_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_308_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_309_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_310_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_311_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_312_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_313_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_314_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_315_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_316_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_317_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_318_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_319_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_320_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_321_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_322_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_323_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_324_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_325_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_326_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_327_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_328_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_329_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_330_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_331_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_332_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_333_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_334_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_335_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_336_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_337_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_338_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_339_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_340_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_341_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_342_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_343_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_344_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_345_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_346_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_347_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_348_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_349_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_350_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_351_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_352_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_353_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_354_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_355_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_356_spectrum.fits',
#  '/Users/dagoret/DATA/CTIODataJune2017_reduced_RG715_v2_prod1/data_08jun17/reduc_20170608_357_spectrum.fits']

# %%
file_toremove=[]
SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_spectrafiles:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_calib_indexes:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_spectrafiles.remove(f)
# Out:
#  remove  reduc_20170608_006_spectrum.fits
#  remove  reduc_20170608_016_spectrum.fits
#  remove  reduc_20170608_023_spectrum.fits
#  remove  reduc_20170608_026_spectrum.fits
#  remove  reduc_20170608_036_spectrum.fits
#  remove  reduc_20170608_046_spectrum.fits
#  remove  reduc_20170608_056_spectrum.fits
#  remove  reduc_20170608_066_spectrum.fits
#  remove  reduc_20170608_076_spectrum.fits
#  remove  reduc_20170608_086_spectrum.fits
#  remove  reduc_20170608_096_spectrum.fits
#  remove  reduc_20170608_106_spectrum.fits
#  remove  reduc_20170608_116_spectrum.fits

# %% [markdown]
# ### find filename for sim spectra

# %%
path_sim1=os.path.join(path_spectrasim,'clearsky')
path_sim2=os.path.join(path_spectrasim,'standard')
path_sim3=os.path.join(path_spectrasim,'merra2')

# %%
search_string=os.path.join(path_sim1,'*.fits')
all_simspectrafiles1=glob.glob(search_string)
all_simspectrafiles1=sorted(all_simspectrafiles1)

# %%
all_simspectrafiles1[:3]
# Out:
# ['../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/clearsky/specsim_20170608_004_spectrum.fits',
#  '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/clearsky/specsim_20170608_005_spectrum.fits',
#  '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/clearsky/specsim_20170608_006_spectrum.fits']

# %%
search_string=os.path.join(path_sim2,'*.fits')
all_simspectrafiles2=glob.glob(search_string)
all_simspectrafiles2=sorted(all_simspectrafiles2)

# %%
all_simspectrafiles2[:3]
# Out:
# ['../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/standard/specsim_20170608_004_spectrum.fits',
#  '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/standard/specsim_20170608_005_spectrum.fits',
#  '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/standard/specsim_20170608_006_spectrum.fits']

# %%
search_string=os.path.join(path_sim3,'*.fits')
all_simspectrafiles3=glob.glob(search_string)
all_simspectrafiles3=sorted(all_simspectrafiles3)

# %%
all_simspectrafiles3[:3]
# Out:
# ['../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/merra2/specsim_20170608_004_spectrum.fits',
#  '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/merra2/specsim_20170608_005_spectrum.fits',
#  '../../SpectractorSim/sim_prod/CTIODataJune2017_reduced_RG715_v2_prod1_SimSpectra/data_08jun17/merra2/specsim_20170608_006_spectrum.fits']

# %% [markdown]
# # Remove bad indexes

# %%
bad_calib_indexes=np.array([6,16,23,26,36,46,56,66,76,86,96,106,116])

# %%
file_toremove=[]
SelectTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_spectrafiles:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_calib_indexes:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_spectrafiles.remove(f)

# %%
file_toremove=[]
SelectTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_simspectrafiles1:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_calib_indexes:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_simspectrafiles1.remove(f)
# Out:
#  remove  specsim_20170608_006_spectrum.fits
#  remove  specsim_20170608_016_spectrum.fits
#  remove  specsim_20170608_023_spectrum.fits
#  remove  specsim_20170608_026_spectrum.fits
#  remove  specsim_20170608_036_spectrum.fits
#  remove  specsim_20170608_046_spectrum.fits
#  remove  specsim_20170608_056_spectrum.fits
#  remove  specsim_20170608_066_spectrum.fits
#  remove  specsim_20170608_076_spectrum.fits
#  remove  specsim_20170608_086_spectrum.fits
#  remove  specsim_20170608_096_spectrum.fits
#  remove  specsim_20170608_106_spectrum.fits
#  remove  specsim_20170608_116_spectrum.fits

# %%
file_toremove=[]
SelectTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_simspectrafiles2:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_calib_indexes:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_simspectrafiles2.remove(f)
# Out:
#  remove  specsim_20170608_006_spectrum.fits
#  remove  specsim_20170608_016_spectrum.fits
#  remove  specsim_20170608_023_spectrum.fits
#  remove  specsim_20170608_026_spectrum.fits
#  remove  specsim_20170608_036_spectrum.fits
#  remove  specsim_20170608_046_spectrum.fits
#  remove  specsim_20170608_056_spectrum.fits
#  remove  specsim_20170608_066_spectrum.fits
#  remove  specsim_20170608_076_spectrum.fits
#  remove  specsim_20170608_086_spectrum.fits
#  remove  specsim_20170608_096_spectrum.fits
#  remove  specsim_20170608_106_spectrum.fits
#  remove  specsim_20170608_116_spectrum.fits

# %%
file_toremove=[]
SelectTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)
for ffn in all_simspectrafiles3:
    fn=ffn.split('/')[-1]
    sel_index= int(re.findall(SelectTagRe,fn)[0])
    if sel_index in bad_calib_indexes:
        print ' remove ', fn
        file_toremove.append(ffn)
for f in file_toremove:
    all_simspectrafiles3.remove(f)
# Out:
#  remove  specsim_20170608_006_spectrum.fits
#  remove  specsim_20170608_016_spectrum.fits
#  remove  specsim_20170608_023_spectrum.fits
#  remove  specsim_20170608_026_spectrum.fits
#  remove  specsim_20170608_036_spectrum.fits
#  remove  specsim_20170608_046_spectrum.fits
#  remove  specsim_20170608_056_spectrum.fits
#  remove  specsim_20170608_066_spectrum.fits
#  remove  specsim_20170608_076_spectrum.fits
#  remove  specsim_20170608_086_spectrum.fits
#  remove  specsim_20170608_096_spectrum.fits
#  remove  specsim_20170608_106_spectrum.fits
#  remove  specsim_20170608_116_spectrum.fits

# %% [markdown]
# # which filters

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='filter', data=sel2_obs)
plt.grid(True)

# %% [markdown]
# # which are the dispersers ?

# %%
plt.figure(figsize=(5,3))
sns.countplot(y='disperser', data=sel2_obs)
plt.grid(True)

# %%
sel_obs_Ron200=sel2_obs.loc[sel2_obs['disperser'].isin(['Ron200'])]

# %%
sel_obs_Thor300=sel2_obs.loc[sel2_obs['disperser'].isin(['Thor300'])]

# %%
sel_obs_HoloPhP=sel2_obs.loc[sel2_obs['disperser'].isin(['HoloPhP'])]

# %%
sel_obs_HoloPhAg=sel2_obs.loc[sel2_obs['disperser'].isin(['HoloPhAg'])]

# %%
sel_obs_HoloAmAg=sel2_obs.loc[sel2_obs['disperser'].isin(['HoloAmAg'])]

# %% [markdown]
# # Show the spectra

# %%
def PlotSpectra(the_filelist,the_obs,the_searchtag,the_title,Flag_corr_wl=False):
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser
    
    plt.figure(figsize=(10,8))
    for the_file in the_filelist:
        idx=get_index_from_filename(the_file,the_searchtag)
        if idx in the_selected_indexes:
            if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
            else:
                time_correction=0
            
            hdu = fits.open(the_file)
            data=hdu[0].data
            wl=data[0]+time_correction
            fl=data[1]
            plt.plot(wl,fl)
    plt.grid()    
    plt.title(the_title)
    plt.xlabel("$\lambda$ (nm)")

# %% [markdown]
# ## Show the reconstructed spectra

# %%
SearchTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)
print SearchTagRe
# Out:
# ^reduc_20170608_([0-9]+)_spectrum.fits$

# %% [markdown]
# ### Ronchi 200 spectra

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Ronchi200"

# %%
PlotSpectra(all_spectrafiles,sel_obs_Ron200,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### Thor 300

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Thor300"

# %%
PlotSpectra(all_spectrafiles,sel_obs_Thor300,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### HoloPhP

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhP"

# %%
PlotSpectra(all_spectrafiles,sel_obs_HoloPhP,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### HoloPhAg

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhAg"

# %%
PlotSpectra(all_spectrafiles,sel_obs_HoloPhAg,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ### HoloAmAg

# %%
thetitle="Reconstructed spectra for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloAmAg"

# %%
PlotSpectra(all_spectrafiles,sel_obs_HoloAmAg,SearchTagRe,thetitle,Flag_corr_wl=True)

# %% [markdown]
# ## Show the simulated spectra

# %%
SearchTagRe='^specsim_%s_([0-9]+)_spectrum.fits$' % (date)

# %% [markdown]
# ### Clear sky

# %%
thetitle="sim spectra for night (clearsky) "+All_Subdirs[idx_sel_subdir]+' target :'+list_of_objects_str

# %%
PlotSpectra(all_simspectrafiles1,sel2_obs,SearchTagRe,thetitle)

# %% [markdown]
# ### standard sky

# %%
thetitle="sim spectra for night (standard) "+All_Subdirs[idx_sel_subdir]+' target :'+list_of_objects_str

# %%
PlotSpectra(all_simspectrafiles2,sel2_obs,SearchTagRe,thetitle)

# %% [markdown]
# ### merra2 sky

# %%
thetitle="sim spectra for night (merra2) "+All_Subdirs[idx_sel_subdir]+' target :'+list_of_objects_str

# %%
PlotSpectra(all_simspectrafiles3,sel2_obs,SearchTagRe,thetitle)

# %% [markdown]
# # Spectra ratio data/sim

# %%
def PlotSpectraRatio(the_filelist,path_tosims,the_obs,the_searchtag,the_title,Flag_corr_wl=False,XMIN=400,XMAX=1000.):
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser
    
    plt.figure(figsize=(10,8))
    for the_file in the_filelist:  # loop on reconstruted spectra
        idx=get_index_from_filename(the_file,the_searchtag)
        if idx in the_selected_indexes:   
            
            if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
            else:
                time_correction=0
            
            
            # check if tthe index is in the disperser indexes 
            basefn=os.path.basename(the_file)                  # basename of reconstruced spectra
            basefn2=basefn.replace('reduc','specsim')  # reconstruct the simulation filename
            the_filesim=os.path.join(path_tosims,basefn2)  # add the path for the simulated file
            
            hdu1 = fits.open(the_file)
            data1=hdu1[0].data
            wl1=data1[0]+time_correction
            fl1=data1[1]
            
            # extend range for (wl1,fl1)
            wl1=np.insert(wl1,0,WL[0])
            fl1=np.insert(fl1,0,0.)
            
            wl1=np.append(wl1,WL[-1])
            fl1=np.append(fl1,0.)
            
            hdu2 = fits.open(the_filesim)
            data2=hdu2[0].data
            wl2=data2[0]
            fl2=data2[1]
            
            func = interpolate.interp1d(wl1, fl1)
            fl0=func(WL)
            
            plt.plot(WL,fl0/fl2)
    plt.xlim(XMIN,XMAX)
    plt.grid()    
    plt.title(the_title)
    plt.xlabel("$\lambda$ (nm)")   
    plt.ylabel("spectra ratio")

# %%
def PlotSpectraLogRatio(the_filelist,path_tosims,the_obs,the_searchtag,the_title,Flag_corr_wl=False,XMIN=400,XMAX=1000.):
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser
    
    plt.figure(figsize=(10,8))
    for the_file in the_filelist:  # loop on reconstruted spectra
        idx=get_index_from_filename(the_file,the_searchtag)
        
        if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
        else:
                time_correction=0
        
        
        if idx in the_selected_indexes:                # check if tthe index is in the disperser indexes 
            basefn=os.path.basename(the_file)                  # basename of reconstruced spectra
            basefn2=basefn.replace('reduc','specsim')  # reconstruct the simulation filename
            the_filesim=os.path.join(path_tosims,basefn2)  # add the path for the simulated file
            
            hdu1 = fits.open(the_file)
            data1=hdu1[0].data
            wl1=data1[0]+time_correction
            fl1=data1[1]
            
            # extend range for (wl1,fl1)
            wl1=np.insert(wl1,0,WL[0])
            fl1=np.insert(fl1,0,0.)
            
            wl1=np.append(wl1,WL[-1])
            fl1=np.append(fl1,0.)
            
            hdu2 = fits.open(the_filesim)
            data2=hdu2[0].data
            wl2=data2[0]
            fl2=data2[1]
            
            func = interpolate.interp1d(wl1, fl1)
            fl0=func(WL)
            
            plt.plot(WL,2.5*(np.log10(fl0)-np.log10(fl2)))
    plt.xlim(XMIN,XMAX)
    plt.grid()    
    plt.title(the_title)
    plt.xlabel("$\lambda$ (nm)")  
    plt.ylabel("log of spectra ratio (mag)")

# %%
def SaveSpectraRatio(the_filelist,path_tosims,the_obs,the_searchtag,the_ratio_file,Flag_corr_wl=False):
    
    all_ratio_arr=np.zeros((1,len(WL)))
    all_ratio_arr[0,:]=WL
    
    the_selected_indexes=the_obs["index"].values  # get the array of index for that disperser    
    for the_file in the_filelist:  # loop on reconstruted spectra
        idx=get_index_from_filename(the_file,the_searchtag)
        if idx in the_selected_indexes:                # check if tthe index is in the disperser indexes 
            
            
            if FLAG_WL_CORRECTION and Flag_corr_wl:
                time_correction=wlshift[wlshift["index"]==idx].loc[:,"wlshift"].values[0]
            else:
                time_correction=0
            
            
            basefn=os.path.basename(the_file)                  # basename of reconstruced spectra
            basefn2=basefn.replace('reduc','specsim')  # reconstruct the simulation filename
            the_filesim=os.path.join(path_tosims,basefn2)  # add the path for the simulated file
            
            hdu1 = fits.open(the_file)
            header1=data1=hdu1[0].header
            airmass=header1["airmass"]
            target=header1["target"]
            
            data1=hdu1[0].data
            wl1=data1[0]+time_correction
            fl1=data1[1]
            
            # extend range for (wl1,fl1)
            wl1=np.insert(wl1,0,WL[0])
            fl1=np.insert(fl1,0,0.)
            
            wl1=np.append(wl1,WL[-1])
            fl1=np.append(fl1,0.)
            
            hdu2 = fits.open(the_filesim)
            data2=hdu2[0].data
            wl2=data2[0]
            fl2=data2[1]
            
            func = interpolate.interp1d(wl1, fl1)
            fl0=func(WL)
            ratio=fl0/fl2
            new_ratio=np.expand_dims(ratio, axis=0)
            all_ratio_arr=np.append(all_ratio_arr,new_ratio,axis=0)
            
            
    hdu = fits.PrimaryHDU(all_ratio_arr)
    hdul = fits.HDUList([hdu])
    hdul.writeto(the_ratio_file,overwrite=True)
    
    return all_ratio_arr

# %%
SearchTagRe='^reduc_%s_([0-9]+)_spectrum.fits$' % (date)

# %% [markdown]
# ## spectra ratio for Ronchi 400

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Ronchi200"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_Ron200,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_Ron200,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in log10

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_Ron400,SearchTagRe,"ratio_Ron200.fits",Flag_corr_wl=True)

# %%
plt.imshow(arr[1:,:],cmap='jet')

# %% [markdown]
# ## spectra ratio for Thor300

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" Thor300"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim1,sel_obs_Thor300,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_Thor300,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_Thor300,SearchTagRe,"ratio_Thor300.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## spectra ratio for HoloPhP

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhP"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhP,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhP,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in log10

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhP,SearchTagRe,"ratio_HoloPhP.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## Spectrum ratio for HoloPhAg

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloPhAg"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in log10

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloPhAg,SearchTagRe,"ratio_HoloPhAg.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# ## Spectrum ratio for HoloAmAg

# %%
thetitle="Spectra ratio Data/Sim for night "+All_Subdirs[idx_sel_subdir]+" target :"+list_of_objects_str+" HoloAmAg"

# %%
PlotSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloAmAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in divide

# %%
PlotSpectraLogRatio(all_spectrafiles,path_sim3,sel_obs_HoloAmAg,SearchTagRe,thetitle,Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: divide by zero encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in log10
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in subtract

# %%
arr=SaveSpectraRatio(all_spectrafiles,path_sim3,sel_obs_HoloAmAg,SearchTagRe,"ratio_HoloAmAg.fits",Flag_corr_wl=True)
# Out:
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in divide
# /Users/dagoret/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in divide

# %%
# !ls *.fits
# Out:
# ratio_HoloAmAg.fits ratio_HoloPhP.fits  ratio_Ron400.fits
# ratio_HoloPhAg.fits ratio_Ron200.fits   ratio_Thor300.fits
